# %%
from agent import Agent

agent = Agent()

# %%
from langchain_core.runnables.graph import  MermaidDrawMethod
from IPython.display import display, Image

display(
    Image(
        agent.app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
dialog = """
Максим Абрамов: Оля, как вам текущий прогресс по модулю учета товаров? Устраивают ли сроки? 
Оля: Пока всё по графику, но хотелось бы ускорить интеграцию с 1С. Это критично для клиента.
Максим Абрамов: Антон, возьмешь интеграцию? Олег поможет с тестами API.
Антон: Да, разберусь. Олег, подготовь тестовые данные по товарам.
Олег: Хорошо! На сколько позиций нужно?
Оля: Пока хватит 50. Главное — проверить выгрузку в реальном времени.
Максим Абрамов: Оля, а какие функции в приоритете после релиза?
Оля: Модуль прогнозирования спроса. Клиент хочет запустить его до конца квартала.
Максим Абрамов: Это амбициозно. Антон, оцени сроки на ТЗ. Олег, изучи аналогичные решения.
Антон: Дам оценку к пятнице.
Олег: Уже ищу кейсы.
Оля: Еще вопрос: будут ли push-уведомления о критичных остатках?
Максим Абрамов: Да, но после интеграции. Олег, протестируешь сценарии оповещений?
Олег: Конечно! Антон, подскажешь, как имитировать низкий остаток?
Антон: Создадим тестовый склад. Напишу инструкцию.
Максим Абрамов: Оля, вас устроит, если релиз модуля 1С будет 20-го, а прогнозирование — через месяц?
Оля: Да, но с условием: сначала покажем демо клиенту.
Максим Абрамов: Хорошо. Антон — демо-версия к 15-му, Олег — подготовь кейсы для презентации.
Антон: Ясно.
Олег: Успеем!
Оля: Отлично. Жду обновлений.
"""

# %%
agent.run(dialog)
# Out:
# INFO:logger:state:
# input='\nМаксим Абрамов: Оля, как вам текущий прогресс по модулю учета товаров? Устраивают ли сроки? \nОля: Пока всё по графику, но хотелось бы ускорить интеграцию с 1С. Это критично для клиента.\nМаксим Абрамов: Антон, возьмешь интеграцию? Олег поможет с тестами API.\nАнтон: Да, разберусь. Олег, подготовь тестовые данные по товарам.\nОлег: Хорошо! На сколько позиций нужно?\nОля: Пока хватит 50. Главное — проверить выгрузку в реальном времени.\nМаксим Абрамов: Оля, а какие функции в приоритете после релиза?\nОля: Модуль прогнозирования спроса. Клиент хочет запустить его до конца квартала.\nМаксим Абрамов: Это амбициозно. Антон, оцени сроки на ТЗ. Олег, изучи аналогичные решения.\nАнтон: Дам оценку к пятнице.\nОлег: Уже ищу кейсы.\nОля: Еще вопрос: будут ли push-уведомления о критичных остатках?\nМаксим Абрамов: Да, но после интеграции. Олег, протестируешь сценарии оповещений?\nОлег: Конечно! Антон, подскажешь, как имитировать низкий остаток?\nАнтон: Создадим тестовый склад. Напишу инструкцию.\nМаксим Абрамов: Оля, вас устроит, если релиз модуля 1С будет 20-го, а прогнозирование — через месяц?\nОля: Да, но с условием: сначала покажем демо клиенту.\nМаксим Абрамов: Хорошо. Антон — демо-версия к 15-му, Олег — подготовь кейсы для презентации.\nАнтон: Ясно.\nОлег: Успеем!\nОля: Отлично. Жду обновлений.\n' dialog=None names=None validate_result=None users=None accounts=None extracted_tasks=None summary=None feedback=None report=None tasks=None
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:openai._base_client:Retrying request to /chat/completions in 0.498424 seconds
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:logger:dialog validate result: valid dialog
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 agent.run(dialog)
#
# File c:\Users\abram\practice\Meetings_agent\agent.py:74, in Agent.run(self, user_input)
#      72 self.state.input = user_input
#      73 logger.info(f'state:\n{self.state}')
# ---> 74 self.state = self.app.invoke(self.state)
#      76 return self._postprocessing(self.state)
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langgraph\pregel\main.py:3019, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, **kwargs)
#    3016 chunks: list[dict[str, Any] | Any] = []
#    3017 interrupts: list[Interrupt] = []
# -> 3019 for chunk in self.stream(
#    3020     input,
#    3021     config,
#    3022     context=context,
#    3023     stream_mode=["updates", "values"]
#    3024     if stream_mode == "values"
#    3025     else stream_mode,
#    3026     print_mode=print_mode,
#    3027     output_keys=output_keys,
#    3028     interrupt_before=interrupt_before,
#    3029     interrupt_after=interrupt_after,
#    3030     **kwargs,
#    3031 ):
#    3032     if stream_mode == "values":
#    3033         if len(chunk) == 2:
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langgraph\pregel\main.py:2651, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2649 for task in loop.match_cached_writes():
#    2650     loop.output_writes(task.id, task.writes, cached=True)
# -> 2651 for _ in runner.tick(
#    2652     [t for t in loop.tasks.values() if not t.writes],
#    2653     timeout=self.step_timeout,
#    2654     get_waiter=get_waiter,
#    2655     schedule_task=loop.accept_push,
#    2656 ):
#    2657     # emit output
#    2658     yield from _output(
#    2659         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2660     )
#    2661 loop.after_tick()
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langgraph\pregel\_runner.py:162, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     160 t = tasks[0]
#     161 try:
# --> 162     run_with_retry(
#     163         t,
#     164         retry_policy,
#     165         configurable={
#     166             CONFIG_KEY_CALL: partial(
#     167                 _call,
#     168                 weakref.ref(t),
#     169                 retry_policy=retry_policy,
#     170                 futures=weakref.ref(futures),
#     171                 schedule_task=schedule_task,
#     172                 submit=self.submit,
#     173             ),
#     174         },
#     175     )
#     176     self.commit(t, None)
#     177 except Exception as exc:
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langgraph\pregel\_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langgraph\_internal\_runnable.py:646, in RunnableSeq.invoke(self, input, config, **kwargs)
#     644     # run in context
#     645     with set_config_context(config, run) as context:
# --> 646         input = context.run(step.invoke, input, config, **kwargs)
#     647 else:
#     648     input = step.invoke(input, config)
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langgraph\_internal\_runnable.py:390, in RunnableCallable.invoke(self, input, config, **kwargs)
#     388         run_manager.on_chain_end(ret)
#     389 else:
# --> 390     ret = self.func(*args, **kwargs)
#     391 if self.recurse and isinstance(ret, Runnable):
#     392     return ret.invoke(input, config)
#
# File c:\Users\abram\practice\Meetings_agent\utils\nodes.py:88, in summary_node(state)
#      87 def summary_node(state: AgentState) -> AgentState:
# ---> 88     response = _llm(input={'query':state.dialog}, template=SYSTEM_SUMMARY_TEMPLATE, validator=None)
#      89     state.summary = response
#      90     logger.info('summary is done')
#
# File c:\Users\abram\practice\Meetings_agent\utils\llm.py:37, in LLMWorker.__call__(self, input, template, validator)
#      34     llm = self.llm
#      36 chain = RunnablePassthrough() | prompt | llm
# ---> 37 out = chain.invoke(input)
#      39 if validator:
#      40     out = out.result
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langchain_core\runnables\base.py:3046, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3044                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3045             else:
# -> 3046                 input_ = context.run(step.invoke, input_, config)
#    3047 # finish the root run
#    3048 except BaseException as e:
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langchain_core\language_models\chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)
#     390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
#     397             stop=stop,
#     398             callbacks=config.get("callbacks"),
#     399             tags=config.get("tags"),
#     400             metadata=config.get("metadata"),
#     401             run_name=config.get("run_name"),
#     402             run_id=config.pop("run_id", None),
#     403             **kwargs,
#     404         ).generations[0][0],
#     405     ).message
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langchain_core\language_models\chat_models.py:980, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     971 @override
#     972 def generate_prompt(
#     973     self,
#    (...)
#     977     **kwargs: Any,
#     978 ) -> LLMResult:
#     979     prompt_messages = [p.to_messages() for p in prompts]
# --> 980     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langchain_core\language_models\chat_models.py:799, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     796 for i, m in enumerate(input_messages):
#     797     try:
#     798         results.append(
# --> 799             self._generate_with_cache(
#     800                 m,
#     801                 stop=stop,
#     802                 run_manager=run_managers[i] if run_managers else None,
#     803                 **kwargs,
#     804             )
#     805         )
#     806     except BaseException as e:
#     807         if run_managers:
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langchain_core\language_models\chat_models.py:1045, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1043     result = generate_from_stream(iter(chunks))
#    1044 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1045     result = self._generate(
#    1046         messages, stop=stop, run_manager=run_manager, **kwargs
#    1047     )
#    1048 else:
#    1049     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\langchain_openai\chat_models\base.py:1130, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1128     generation_info = {"headers": dict(raw_response.headers)}
#    1129 else:
# -> 1130     response = self.client.create(**payload)
#    1131 return self._create_chat_result(response, generation_info)
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\openai\resources\chat\completions\completions.py:1087, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1044 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1045 def create(
#    1046     self,
#    (...)
#    1084     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1085 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1086     validate_response_format(response_format)
# -> 1087     return self._post(
#    1088         "/chat/completions",
#    1089         body=maybe_transform(
#    1090             {
#    1091                 "messages": messages,
#    1092                 "model": model,
#    1093                 "audio": audio,
#    1094                 "frequency_penalty": frequency_penalty,
#    1095                 "function_call": function_call,
#    1096                 "functions": functions,
#    1097                 "logit_bias": logit_bias,
#    1098                 "logprobs": logprobs,
#    1099                 "max_completion_tokens": max_completion_tokens,
#    1100                 "max_tokens": max_tokens,
#    1101                 "metadata": metadata,
#    1102                 "modalities": modalities,
#    1103                 "n": n,
#    1104                 "parallel_tool_calls": parallel_tool_calls,
#    1105                 "prediction": prediction,
#    1106                 "presence_penalty": presence_penalty,
#    1107                 "reasoning_effort": reasoning_effort,
#    1108                 "response_format": response_format,
#    1109                 "seed": seed,
#    1110                 "service_tier": service_tier,
#    1111                 "stop": stop,
#    1112                 "store": store,
#    1113                 "stream": stream,
#    1114                 "stream_options": stream_options,
#    1115                 "temperature": temperature,
#    1116                 "tool_choice": tool_choice,
#    1117                 "tools": tools,
#    1118                 "top_logprobs": top_logprobs,
#    1119                 "top_p": top_p,
#    1120                 "user": user,
#    1121                 "web_search_options": web_search_options,
#    1122             },
#    1123             completion_create_params.CompletionCreateParamsStreaming
#    1124             if stream
#    1125             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1126         ),
#    1127         options=make_request_options(
#    1128             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1129         ),
#    1130         cast_to=ChatCompletion,
#    1131         stream=stream or False,
#    1132         stream_cls=Stream[ChatCompletionChunk],
#    1133     )
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\openai\_base_client.py:1249, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1235 def post(
#    1236     self,
#    1237     path: str,
#    (...)
#    1244     stream_cls: type[_StreamT] | None = None,
#    1245 ) -> ResponseT | _StreamT:
#    1246     opts = FinalRequestOptions.construct(
#    1247         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1248     )
# -> 1249     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\openai\_base_client.py:972, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     970 response = None
#     971 try:
# --> 972     response = self._client.send(
#     973         request,
#     974         stream=stream or self._should_stream_response_body(request=request),
#     975         **kwargs,
#     976     )
#     977 except httpx.TimeoutException as err:
#     978     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpx\_client.py:928, in Client.send(self, request, stream, auth, follow_redirects)
#     926 except BaseException as exc:
#     927     response.close()
# --> 928     raise exc
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpx\_client.py:922, in Client.send(self, request, stream, auth, follow_redirects)
#     920 try:
#     921     if not stream:
# --> 922         response.read()
#     924     return response
#     926 except BaseException as exc:
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpx\_models.py:881, in Response.read(self)
#     877 """
#     878 Read and return the response content.
#     879 """
#     880 if not hasattr(self, "_content"):
# --> 881     self._content = b"".join(self.iter_bytes())
#     882 return self._content
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\soft\miniconda\envs\meetings_agent\lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File c:\soft\miniconda\envs\meetings_agent\lib\ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File c:\soft\miniconda\envs\meetings_agent\lib\ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
agent.state
# Out:
# {'input': '\nМаксим Абрамов: Оля, как вам текущий прогресс по модулю учета товаров? Устраивают ли сроки? \nОля: Пока всё по графику, но хотелось бы ускорить интеграцию с 1С. Это критично для клиента.\nМаксим Абрамов: Антон, возьмешь интеграцию? Олег поможет с тестами API.\nАнтон: Да, разберусь. Олег, подготовь тестовые данные по товарам.\nОлег: Хорошо! На сколько позиций нужно?\nОля: Пока хватит 50. Главное — проверить выгрузку в реальном времени.\nМаксим Абрамов: Оля, а какие функции в приоритете после релиза?\nОля: Модуль прогнозирования спроса. Клиент хочет запустить его до конца квартала.\nМаксим Абрамов: Это амбициозно. Антон, оцени сроки на ТЗ. Олег, изучи аналогичные решения.\nАнтон: Дам оценку к пятнице.\nОлег: Уже ищу кейсы.\nОля: Еще вопрос: будут ли push-уведомления о критичных остатках?\nМаксим Абрамов: Да, но после интеграции. Олег, протестируешь сценарии оповещений?\nОлег: Конечно! Антон, подскажешь, как имитировать низкий остаток?\nАнтон: Создадим тестовый склад. Напишу инструкцию.\nМаксим Абрамов: Оля, вас устроит, если релиз модуля 1С будет 20-го, а прогнозирование — через месяц?\nОля: Да, но с условием: сначала покажем демо клиенту.\nМаксим Абрамов: Хорошо. Антон — демо-версия к 15-му, Олег — подготовь кейсы для презентации.\nАнтон: Ясно.\nОлег: Успеем!\nОля: Отлично. Жду обновлений.\n',
#  'dialog': '\nМаксим Абрамов: Оля, как вам текущий прогресс по модулю учета товаров? Устраивают ли сроки? \nОля: Пока всё по графику, но хотелось бы ускорить интеграцию с 1С. Это критично для клиента.\nМаксим Абрамов: Антон, возьмешь интеграцию? Олег поможет с тестами API.\nАнтон: Да, разберусь. Олег, подготовь тестовые данные по товарам.\nОлег: Хорошо! На сколько позиций нужно?\nОля: Пока хватит 50. Главное — проверить выгрузку в реальном времени.\nМаксим Абрамов: Оля, а какие функции в приоритете после релиза?\nОля: Модуль прогнозирования спроса. Клиент хочет запустить его до конца квартала.\nМаксим Абрамов: Это амбициозно. Антон, оцени сроки на ТЗ. Олег, изучи аналогичные решения.\nАнтон: Дам оценку к пятнице.\nОлег: Уже ищу кейсы.\nОля: Еще вопрос: будут ли push-уведомления о критичных остатках?\nМаксим Абрамов: Да, но после интеграции. Олег, протестируешь сценарии оповещений?\nОлег: Конечно! Антон, подскажешь, как имитировать низкий остаток?\nАнтон: Создадим тестовый склад. Напишу инструкцию.\nМаксим Абрамов: Оля, вас устроит, если релиз модуля 1С будет 20-го, а прогнозирование — через месяц?\nОля: Да, но с условием: сначала покажем демо клиенту.\nМаксим Абрамов: Хорошо. Антон — демо-версия к 15-му, Олег — подготовь кейсы для презентации.\nАнтон: Ясно.\nОлег: Успеем!\nОля: Отлично. Жду обновлений.\n',
#  'names': ['', 'Максим Абрамов', 'Антон', 'Олег', 'Оля'],
#  'validate_result': 'valid dialog',
#  'users': [{'name': 'Максим Абрамов', 'id': '62010cc3ff9289006eeaf4c6'},
#   {'name': 'Олег', 'id': '62010ca87334070067539329'},
#   {'name': 'Антон', 'id': '712020:ffa851dd-cc8b-45b3-80d6-077c48cf85be'}],
#  'accounts': {'Максим Абрамов': '62010cc3ff9289006eeaf4c6',
#   'Олег': '62010ca87334070067539329',
#   'Антон': '712020:ffa851dd-cc8b-45b3-80d6-077c48cf85be'},
#  'tasks': [{'owner': 'Максим Абрамов',
#    'name': 'Интеграция с 1С',
#    'description': 'Ускорить интеграцию с 1С, так как это критично для клиента.',
#    'reported by': 'Антон'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Подготовка тестовых данных по товарам',
#    'description': 'Подготовить тестовые данные по товарам для тестирования API. Оля указала, что пока хватит 50 позиций, важно проверить выгрузку в реальном времени.',
#    'reported by': 'Олег'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Оценка сроков ТЗ для модуля прогнозирования спроса',
#    'description': 'Оценить сроки на ТЗ для модуля прогнозирования спроса. Клиент хочет запустить его до конца квартала.',
#    'reported by': 'Антон'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Изучение аналогичных решений для модуля прогнозирования сппроса',
#    'description': 'Изучить аналогичные решения для модуля прогнозирования спроса.',
#    'reported by': 'Олег'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Протестировать сценарии оповещений',
#    'description': 'Протестировать сценарии оповещений о критичных остатках. Это будет после интеграции с 1С.',
#    'reported by': 'Олег'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Имитация низкого остатка',
#    'description': 'Антон должен подсказать, как имитировать низкий остаток для тестирования сценариев оповещений.',
#    'reported by': 'Антон'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Создание тестового склада',
#    'description': 'Создать тестовый склад для имитации низкого остатка. Антон должен написать инструкцию по этому.',
#    'reported by': 'Антон'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Подготовка демо-версии модуля 1С',
#    'description': 'Подготовить демо-версию модуля 1С к 15-му числу. Это необходимо для демонстрации клиенту.',
#    'reported by': 'Антон'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Подготовка кейсов для презентации',
#    'description': 'Подготовить кейсы для презентации модуля прогнозирования спроса. Это нужно для демонстрации клиента.',
#    'reported by': 'Олег'}],
#  'summary': '**Резюме:**  \n**Ключевые темы:** Прогресс по модулю учёта товаров, интеграция с 1С, модуль прогнозирования спроса, push-уведомления о критичных остатках.  \n**Решения:**  \n- Антон берёт на себя интеграцию с 1С и подготовку демо-версии к 15-му.  \n- Олег занимается тестированием API, изучением аналогичных решений и подготовкой кейсов для презентации.  \n- Определены сроки: релиз модуля 1С — 20-е, прогнозирование спроса — через месяц.  \n**Действия:**  \n- Олег подготовит тестовые данные по товарам (50 позиций) для проверки выгрузки в реальном времени.  \n- Антон создаст тестовый склад и напишет инструкцию по имитации низкого остатка.  \n- Антон оценит сроки реализации прогнозирования спроса по ТЗ к пятнице.  \n**Договорённости:**  \n- Клиенту будет показано демо-представление модуля 1С до релиза.  \n- Push-уведомления будут реализованы после завершения интеграции.  \n- Все участники подтверждают выполнение задач.',
#  'feedback': None,
#  'report': 'Анализ прошедшей встречи готов.\n\n**Краткий пересказ встречи**:\n\n**Резюме:**  \n**Ключевые темы:** Прогресс по модулю учёта товаров, интеграция с 1С, модуль прогнозирования спроса, push-уведомления о критичных остатках.  \n**Решения:**  \n- Антон берёт на себя интеграцию с 1С и подготовку демо-версии к 15-му.  \n- Олег занимается тестированием API, изучением аналогичных решений и подготовкой кейсов для презентации.  \n- Определены сроки: релиз модуля 1С — 20-е, прогнозирование спроса — через месяц.  \n**Действия:**  \n- Олег подготовит тестовые данные по товарам (50 позиций) для проверки выгрузки в реальном времени.  \n- Антон создаст тестовый склад и напишет инструкцию по имитации низкого остатка.  \n- Антон оценит сроки реализации прогнозирования спроса по ТЗ к пятнице.  \n**Договорённости:**  \n- Клиенту будет показано демо-представление модуля 1С до релиза.  \n- Push-уведомления будут реализованы после завершения интеграции.  \n- Все участники подтверждают выполнение задач.\n\n**Результаты встречи**:\n\n- **Задача**: "Интеграция с 1С"\n\n    **Описание**: Ускорить интеграцию с 1С, так как это критично для клиента.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Подготовка тестовых данных по товарам"\n\n    **Описание**: Подготовить тестовые данные по товарам для тестирования API. Оля указала, что пока хватит 50 позиций, важно проверить выгрузку в реальном времени.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег\n\n---\n- **Задача**: "Оценка сроков ТЗ для модуля прогнозирования спроса"\n\n    **Описание**: Оценить сроки на ТЗ для модуля прогнозирования спроса. Клиент хочет запустить его до конца квартала.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Изучение аналогичных решений для модуля прогнозирования сппроса"\n\n    **Описание**: Изучить аналогичные решения для модуля прогнозирования спроса.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег\n\n---\n- **Задача**: "Протестировать сценарии оповещений"\n\n    **Описание**: Протестировать сценарии оповещений о критичных остатках. Это будет после интеграции с 1С.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег\n\n---\n- **Задача**: "Имитация низкого остатка"\n\n    **Описание**: Антон должен подсказать, как имитировать низкий остаток для тестирования сценариев оповещений.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Создание тестового склада"\n\n    **Описание**: Создать тестовый склад для имитации низкого остатка. Антон должен написать инструкцию по этому.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Подготовка демо-версии модуля 1С"\n\n    **Описание**: Подготовить демо-версию модуля 1С к 15-му числу. Это необходимо для демонстрации клиенту.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Подготовка кейсов для презентации"\n\n    **Описание**: Подготовить кейсы для презентации модуля прогнозирования спроса. Это нужно для демонстрации клиента.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег\n\n---\n'}

# %%
feedback = """Убери из описания задач слова по типу "для заказчика", "для клиента" и т.п."""
agent.run(feedback)
# Out:
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:logger:dialog validate result: not dialog
# dialog:
#
# Максим Абрамов: Оля, как вам текущий прогресс по модулю учета товаров? Устраивают ли сроки?
# Оля: Пока всё по графику, но хотелось бы ускорить интеграцию с 1С. Это критично для клиента.
# Максим Абрамов: Антон, возьмешь интеграцию? Олег поможет с тестами API.
# Антон: Да, разберусь. Олег, подготовь тестовые данные по товарам.
# Олег: Хорошо! На сколько позиций нужно?
# Оля: Пока хватит 50. Главное — проверить выгрузку в реальном времени.
# Максим Абрамов: Оля, а какие функции в приоритете после релиза?
# Оля: Модуль прогнозирования спроса. Клиент хочет запустить его до конца квартала.
# Максим Абрамов: Это амбициозно. Антон, оцени сроки на ТЗ. Олег, изучи аналогичные решения.
# Антон: Дам оценку к пятнице.
# Олег: Уже ищу кейсы.
# Оля: Еще вопрос: будут ли push-уведомления о критичных остатках?
# Максим Абрамов: Да, но после интеграции. Олег, протестируешь сценарии оповещений?
# Олег: Конечно! Антон, подскажешь, как имитировать низкий остаток?
# Антон: Создадим тестовый склад. Напишу инструкцию.
# Максим Абрамов: Оля, вас устроит, если релиз модуля 1С будет 20-го, а прогнозирование — через месяц?
# Оля: Да, но с условием: сначала покажем демо клиенту.
# Максим Абрамов: Хорошо. Антон — демо-версия к 15-му, Олег — подготовь кейсы для презентации.
# Антон: Ясно.
# Олег: Успеем!
# Оля: Отлично. Жду обновлений.
#
# feedback
# Убери из описания задач слова по типу "для заказчика", "для клиента" и т.п.
# report
# Анализ прошедшей встречи готов.
#
# **Краткий пересказ встречи**:
#
# **Резюме:**
# **Ключевые темы:** Прогресс по модулю учёта товаров, интеграция с 1С, модуль прогнозирования спроса, push-уведомления о критичных остатках.
# **Решения:**
# - Антон берёт на себя интеграцию с 1С и подготовку демо-версии к 15-му.
# - Олег занимается тестированием API, изучением аналогичных решений и подготовкой кейсов для презентации.
# - Определены сроки: релиз модуля 1С — 20-е, прогнозирование спроса — через месяц.
# **Действия:**
# - Олег подготовит тестовые данные по товарам (50 позиций) для проверки выгрузки в реальном времени.
# - Антон создаст тестовый склад и напишет инструкцию по имитации низкого остатка.
# - Антон оценит сроки реализации прогнозирования спроса по ТЗ к пятнице.
# **Договорённости:**
# - Клиенту будет показано демо-представление модуля 1С до релиза.
# - Push-уведомления будут реализованы после завершения интеграции.
# - Все участники подтверждают выполнение задач.
#
# **Результаты встречи**:
#
# - **Задача**: "Интеграция с 1С"
#
#     **Описание**: Ускорить интеграцию с 1С, так как это критично для клиента.
#
#     **Создатель**: Максим Абрамов
#
#     **Исполнитель**: Антон
#
# ---
# - **Задача**: "Подготовка тестовых данных по товарам"
#
#     **Описание**: Подготовить тестовые данные по товарам для тестирования API. Оля указала, что пока хватит 50 позиций, важно проверить выгрузку в реальном времени.
#
#     **Создатель**: Максим Абрамов
#
#     **Исполнитель**: Олег
#
# ---
# - **Задача**: "Оценка сроков ТЗ для модуля прогнозирования спроса"
#
#     **Описание**: Оценить сроки на ТЗ для модуля прогнозирования спроса. Клиент хочет запустить его до конца квартала.
#
#     **Создатель**: Максим Абрамов
#
#     **Исполнитель**: Антон
#
# ---
# - **Задача**: "Изучение аналогичных решений для модуля прогнозирования сппроса"
#
#     **Описание**: Изучить аналогичные решения для модуля прогнозирования спроса.
#
#     **Создатель**: Максим Абрамов
#
#     **Исполнитель**: Олег
#
# ---
# - **Задача**: "Протестировать сценарии оповещений"
#
#     **Описание**: Протестировать сценарии оповещений о критичных остатках. Это будет после интеграции с 1С.
#
#     **Создатель**: Максим Абрамов
#
#     **Исполнитель**: Олег
#
# ---
# - **Задача**: "Имитация низкого остатка"
#
#     **Описание**: Антон должен подсказать, как имитировать низкий остаток для тестирования сценариев оповещений.
#
#     **Создатель**: Максим Абрамов
#
#     **Исполнитель**: Антон
#
# ---
# - **Задача**: "Создание тестового склада"
#
#     **Описание**: Создать тестовый склад для имитации низкого остатка. Антон должен написать инструкцию по этому.
#
#     **Создатель**: Максим Абрамов
#
#     **Исполнитель**: Антон
#
# ---
# - **Задача**: "Подготовка демо-версии модуля 1С"
#
#     **Описание**: Подготовить демо-версию модуля 1С к 15-му числу. Это необходимо для демонстрации клиенту.
#
#     **Создатель**: Максим Абрамов
#
#     **Исполнитель**: Антон
#
# ---
# - **Задача**: "Подготовка кейсов для презентации"
#
#     **Описание**: Подготовить кейсы для презентации модуля прогнозирования спроса. Это нужно для демонстрации клиента.
#
#     **Создатель**: Максим Абрамов
#
#     **Исполнитель**: Олег
#
# ---
# INFO:httpx:HTTP Request: POST https://openrouter.ai/api/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:logger:applying feedback is done
# 'Анализ прошедшей встречи готов.\n\n**Краткий пересказ встречи**:\n\n**Резюме:**  \n**Ключевые темы:** Прогресс по модулю учёта товаров, интеграция с 1С, модуль прогнозирования спроса, push-уведомления о критичных остатках.  \n**Решения:**  \n- Антон берёт на себя интеграцию с 1С и подготовку демо-версии к 15-му.  \n- Олег занимается тестированием API, изучением аналогичных решений и подготовкой кейсов для презентации.  \n- Определены сроки: релиз модуля 1С — 20-е, прогнозирование спроса — через месяц.  \n**Действия:**  \n- Олег подготовит тестовые данные по товарам (50 позиций) для проверки выгрузки в реальном времени.  \n- Антон создаст тестовый склад и напишет инструкцию по имитации низкого остатка.  \n- Антон оценит сроки реализации прогнозирования спроса по ТЗ к пятнице.  \n**Договорённости:**  \n- Клиенту будет показано демо-представление модуля 1С до релиза.  \n- Push-уведомления будут реализованы после завершения интеграции.  \n- Все участники подтверждают выполнение задач.\n\n**Результаты встречи**:\n\n- **Задача**: "Интеграция с 1С"\n\n    **Описание**: Ускорить интеграцию с 1С, так как это критично.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Подготовка тестовых данных по товарам"\n\n    **Описание**: Подготовить тестовые данные по товарам для тестирования API. Оля указала, что пока хватит 50 позиций, важно проверить выгрузку в реальном времени.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег\n\n---\n- **Задача**: "Оценка сроков ТЗ для модуля прогнозирования спроса"\n\n    **Описание**: Оценить сроки на ТЗ для модуля прогнозирования спроса. Клиент хочет запустить его до конца квартала.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Изучение аналогичных решений для модуля прогнозирования спроса"\n\n    **Описание**: Изучить аналогичные решения для модуля прогнозирования спроса.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег\n\n---\n- **Задача**: "Протестировать сценарии оповещений"\n\n    **Описание**: Протестировать сценарии оповещений о критичных остатках. Это будет после интеграции с 1С.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег\n\n---\n- **Задача**: "Имитация низкого остатка"\n\n    **Описание**: Антон должен подсказать, как имитировать низкий остаток для тестирования сценариев оповещений.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Создание тестового склада"\n\n    **Описание**: Создать тестовый склад для имитации низкого остатка. Антон должен написать инструкцию по этому.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Подготовка демо-версии модуля 1С"\n\n    **Описание**: Подготовить демо-версию модуля 1С к 15-му числу. Это необходимо для демонстрации.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Подготовка кейсов для презентации"\n\n    **Описание**: Подготовить кейсы для презентации модуля прогнозирования спроса. Это нужно для презентации.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег'

# %%
agent.state
# Out:
# {'input': 'Убери из описания задач слова по типу "для заказчика", "для клиента" и т.п.',
#  'dialog': '\nМаксим Абрамов: Оля, как вам текущий прогресс по модулю учета товаров? Устраивают ли сроки? \nОля: Пока всё по графику, но хотелось бы ускорить интеграцию с 1С. Это критично для клиента.\nМаксим Абрамов: Антон, возьмешь интеграцию? Олег поможет с тестами API.\nАнтон: Да, разберусь. Олег, подготовь тестовые данные по товарам.\nОлег: Хорошо! На сколько позиций нужно?\nОля: Пока хватит 50. Главное — проверить выгрузку в реальном времени.\nМаксим Абрамов: Оля, а какие функции в приоритете после релиза?\nОля: Модуль прогнозирования спроса. Клиент хочет запустить его до конца квартала.\nМаксим Абрамов: Это амбициозно. Антон, оцени сроки на ТЗ. Олег, изучи аналогичные решения.\nАнтон: Дам оценку к пятнице.\nОлег: Уже ищу кейсы.\nОля: Еще вопрос: будут ли push-уведомления о критичных остатках?\nМаксим Абрамов: Да, но после интеграции. Олег, протестируешь сценарии оповещений?\nОлег: Конечно! Антон, подскажешь, как имитировать низкий остаток?\nАнтон: Создадим тестовый склад. Напишу инструкцию.\nМаксим Абрамов: Оля, вас устроит, если релиз модуля 1С будет 20-го, а прогнозирование — через месяц?\nОля: Да, но с условием: сначала покажем демо клиенту.\nМаксим Абрамов: Хорошо. Антон — демо-версия к 15-му, Олег — подготовь кейсы для презентации.\nАнтон: Ясно.\nОлег: Успеем!\nОля: Отлично. Жду обновлений.\n',
#  'names': ['', 'Максим Абрамов', 'Антон', 'Олег', 'Оля'],
#  'validate_result': 'not dialog',
#  'users': [{'name': 'Максим Абрамов', 'id': '62010cc3ff9289006eeaf4c6'},
#   {'name': 'Олег', 'id': '62010ca87334070067539329'},
#   {'name': 'Антон', 'id': '712020:ffa851dd-cc8b-45b3-80d6-077c48cf85be'}],
#  'accounts': {'Максим Абрамов': '62010cc3ff9289006eeaf4c6',
#   'Олег': '62010ca87334070067539329',
#   'Антон': '712020:ffa851dd-cc8b-45b3-80d6-077c48cf85be'},
#  'tasks': [{'owner': 'Максим Абрамов',
#    'name': 'Интеграция с 1С',
#    'description': 'Ускорить интеграцию с 1С, так как это критично для клиента.',
#    'reported by': 'Антон'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Подготовка тестовых данных по товарам',
#    'description': 'Подготовить тестовые данные по товарам для тестирования API. Оля указала, что пока хватит 50 позиций, важно проверить выгрузку в реальном времени.',
#    'reported by': 'Олег'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Оценка сроков ТЗ для модуля прогнозирования спроса',
#    'description': 'Оценить сроки на ТЗ для модуля прогнозирования спроса. Клиент хочет запустить его до конца квартала.',
#    'reported by': 'Антон'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Изучение аналогичных решений для модуля прогнозирования сппроса',
#    'description': 'Изучить аналогичные решения для модуля прогнозирования спроса.',
#    'reported by': 'Олег'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Протестировать сценарии оповещений',
#    'description': 'Протестировать сценарии оповещений о критичных остатках. Это будет после интеграции с 1С.',
#    'reported by': 'Олег'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Имитация низкого остатка',
#    'description': 'Антон должен подсказать, как имитировать низкий остаток для тестирования сценариев оповещений.',
#    'reported by': 'Антон'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Создание тестового склада',
#    'description': 'Создать тестовый склад для имитации низкого остатка. Антон должен написать инструкцию по этому.',
#    'reported by': 'Антон'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Подготовка демо-версии модуля 1С',
#    'description': 'Подготовить демо-версию модуля 1С к 15-му числу. Это необходимо для демонстрации клиенту.',
#    'reported by': 'Антон'},
#   {'owner': 'Максим Абрамов',
#    'name': 'Подготовка кейсов для презентации',
#    'description': 'Подготовить кейсы для презентации модуля прогнозирования спроса. Это нужно для демонстрации клиента.',
#    'reported by': 'Олег'}],
#  'summary': '**Резюме:**  \n**Ключевые темы:** Прогресс по модулю учёта товаров, интеграция с 1С, модуль прогнозирования спроса, push-уведомления о критичных остатках.  \n**Решения:**  \n- Антон берёт на себя интеграцию с 1С и подготовку демо-версии к 15-му.  \n- Олег занимается тестированием API, изучением аналогичных решений и подготовкой кейсов для презентации.  \n- Определены сроки: релиз модуля 1С — 20-е, прогнозирование спроса — через месяц.  \n**Действия:**  \n- Олег подготовит тестовые данные по товарам (50 позиций) для проверки выгрузки в реальном времени.  \n- Антон создаст тестовый склад и напишет инструкцию по имитации низкого остатка.  \n- Антон оценит сроки реализации прогнозирования спроса по ТЗ к пятнице.  \n**Договорённости:**  \n- Клиенту будет показано демо-представление модуля 1С до релиза.  \n- Push-уведомления будут реализованы после завершения интеграции.  \n- Все участники подтверждают выполнение задач.',
#  'feedback': 'Убери из описания задач слова по типу "для заказчика", "для клиента" и т.п.',
#  'report': 'Анализ прошедшей встречи готов.\n\n**Краткий пересказ встречи**:\n\n**Резюме:**  \n**Ключевые темы:** Прогресс по модулю учёта товаров, интеграция с 1С, модуль прогнозирования спроса, push-уведомления о критичных остатках.  \n**Решения:**  \n- Антон берёт на себя интеграцию с 1С и подготовку демо-версии к 15-му.  \n- Олег занимается тестированием API, изучением аналогичных решений и подготовкой кейсов для презентации.  \n- Определены сроки: релиз модуля 1С — 20-е, прогнозирование спроса — через месяц.  \n**Действия:**  \n- Олег подготовит тестовые данные по товарам (50 позиций) для проверки выгрузки в реальном времени.  \n- Антон создаст тестовый склад и напишет инструкцию по имитации низкого остатка.  \n- Антон оценит сроки реализации прогнозирования спроса по ТЗ к пятнице.  \n**Договорённости:**  \n- Клиенту будет показано демо-представление модуля 1С до релиза.  \n- Push-уведомления будут реализованы после завершения интеграции.  \n- Все участники подтверждают выполнение задач.\n\n**Результаты встречи**:\n\n- **Задача**: "Интеграция с 1С"\n\n    **Описание**: Ускорить интеграцию с 1С, так как это критично.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Подготовка тестовых данных по товарам"\n\n    **Описание**: Подготовить тестовые данные по товарам для тестирования API. Оля указала, что пока хватит 50 позиций, важно проверить выгрузку в реальном времени.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег\n\n---\n- **Задача**: "Оценка сроков ТЗ для модуля прогнозирования спроса"\n\n    **Описание**: Оценить сроки на ТЗ для модуля прогнозирования спроса. Клиент хочет запустить его до конца квартала.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Изучение аналогичных решений для модуля прогнозирования спроса"\n\n    **Описание**: Изучить аналогичные решения для модуля прогнозирования спроса.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег\n\n---\n- **Задача**: "Протестировать сценарии оповещений"\n\n    **Описание**: Протестировать сценарии оповещений о критичных остатках. Это будет после интеграции с 1С.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег\n\n---\n- **Задача**: "Имитация низкого остатка"\n\n    **Описание**: Антон должен подсказать, как имитировать низкий остаток для тестирования сценариев оповещений.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Создание тестового склада"\n\n    **Описание**: Создать тестовый склад для имитации низкого остатка. Антон должен написать инструкцию по этому.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Подготовка демо-версии модуля 1С"\n\n    **Описание**: Подготовить демо-версию модуля 1С к 15-му числу. Это необходимо для демонстрации.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Антон\n\n---\n- **Задача**: "Подготовка кейсов для презентации"\n\n    **Описание**: Подготовить кейсы для презентации модуля прогнозирования спроса. Это нужно для презентации.\n\n    **Создатель**: Максим Абрамов\n\n    **Исполнитель**: Олег'}
